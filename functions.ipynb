# %%
import numpy as np
import numpy_financial as npf
import matplotlib.pyplot as plt

# %% [markdown]
# # Ile będzie wynosiła orientacyjna cena mieszkania za 5 lat?

# %%
np.around(npf.fv(0.05, 5, 0, -120000),2)
# Out:
# 153153.79

# %% [markdown]
# Orientacyjna cena mieszkania za 5 lat będzie wynosiła 153153.79 zł

# %% [markdown]
# # Ile musisz wpłacać do banku każdego miesiąca, aby przy przedstawionej ofercie uzbierać na mieszkanie w ciągu 5 lat?

# %%
np.around(npf.ppmt(0.12/12, 1, 5*12, -153153.79),2)
# Out:
# 1875.28

# %% [markdown]
# Każdego miesiąca musisz wpłacać 1875,28 zł

# %% [markdown]
# # Stwórz wykres przedstawiający, jak w interwałach miesięcznych zmieniać się będzie cena mieszkania (liniowy wzrost w całym okresie) oraz wartość twojej lokaty.

# %%
a=np.linspace(120000,153153.79,60)
per=np.arange(1,5*12+1,dtype=int)
b=np.around(npf.ppmt(0.12/12, per, 5*12, -153153.79),2).cumsum()
plt.plot(a,label='wartość mieszkania')
plt.plot(b,label='wartość lokaty')
plt.legend()
plt.xlabel('Liczba okresów')
plt.ylabel('Wartość inwestycji')
# Out:
# Text(0, 0.5, 'Wartość inwestycji')
